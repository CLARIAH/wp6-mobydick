# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from tf.app import use

# %%
A = use("annotation/mobydick:clone", checkout="clone", hoist=globals())
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/me/github">~/github/annotation/mobydick/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/annotation/mobydick/tf/0.2</span>
#             <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 11.3.1</a>, <a target="_blank" href="https://github.com/annotation/mobydick/blob/main/app" title="annotation/mobydick app">annotation/mobydick/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
# ...

# %%
slotsx = [s for s in F.otype.s("char") if not L.u(s, otype={"chunk", "chapter"})]

# %%
len(slotsx)
# Out:
# 0

# %%
s0 = slotsx[0]
s0
# Out:
# 95

# %%
c0 = F.otype.s("chapter")[-1]

# %%
A.pretty(c0, withNodes=True, multiFeatures=True, baseTypes=set(), full=True)
# Out:
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.annotation.org/mobydick/4 trailer/-1/&lt;3>&amp;version=0.2" title="Show this on the website" sec="4 trailer">4 trailer</a></span></div><div class=" children"><div class="contnr c4    " ><div class="lbl c4  " ><span class="nd">chapter:99 </span> <span class="txtu"><span class="tfsechead ltr"><span class="ltr">4 trailer</span></span></span></div><div class="features"><span class="chapter xft" ><span class="f">chapter=</span>4 trailer</span></div><div class="children hor wrap "><div class="contnr c3   rno " ><div class="lbl c3  " ><span class="nd">chunk:105 </span></div><div class="features"><span class="chunk xft" ><span class="f">chunk=</span>-1</span></div><div class="children hor wrap "><div class="contnr c1   rno " ><div class="lbl c1  " ><span class="nd">trailer:123 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">88 </span> <span
# ...

# %%
feats = {}
for f in Fall():
    val = Fs(f).v(s0)
    if val is not None:
        print(f"{f:<10} = `{val}`")
# Out:
# otype      = `char`

# %%
F.otype.maxSlot
# Out:
# 94
